# %%
# %pip install ollama -qq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from generate_image_ollama import generate_image

# %%
PROMPT = "Broadway roaring 1920s retro future.  Title in neon: ROARING 20s"
generate_image(PROMPT, "broadway.png")
# Out:
# Connecting to Ollama at http://192.168.64.1:11434...
# Generating image with x/flux2-klein...
# Prompt: Broadway roaring 1920s retro future.  Title in neon: ROARING 20s
# ✗ Error generating image: mlx runner failed: 	/Users/runner/work/ollama/ollama/main.go:12 +0x54 (exit: exit status 2) (status code: 500)
# Traceback (most recent call last):
#   File "/workspaces/agent-client-kernel/generate_image_ollama.py", line 21, in generate_image
#     response = client.generate(
#         model=MODEL,
#         prompt=prompt,
#         stream=False
#     )
#   File "/opt/conda/lib/python3.13/site-packages/ollama/_client.py", line 281, in generate
#     return self._request(
#            ~~~~~~~~~~~~~^
#       GenerateResponse,
#       ^^^^^^^^^^^^^^^^^
#     ...<22 lines>...
#       stream=stream,
#       ^^^^^^^^^^^^^^
#     )
#     ^
#   File "/opt/conda/lib/python3.13/site-packages/ollama/_client.py", line 199, in _request
#     return cls(**self._request_raw(*args, **kwargs).json())
# ...

# %% [markdown]
# !["Broadway roaring 1920s retro future"](broadway.png)
