# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# 🔧 bash (pending)✅ Tool 782917311 completed
# 🔧 bash (pending)✅ Tool 741835847 completed
# 🔧 bash (pending)✅ Tool 154011733 completed
# 🔧 edit (pending)
# 🔧 write (pending)✅ Tool 690290880 completed
# You have **35 Jupyter notebooks** in total. Here are the named ones (non-Untitled):
#
# **Example/Agent Notebooks:**
# - `batch pi.ipynb`
# - `broadway.ipynb`
# - `lmstudio agent.ipynb`
# - `pi test.ipynb` (and variations: test 2-6)- `sum agent.ipynb`
# - `sum.ipynb`
# - `weather agent.ipynb`
#
# **Test/Debug Notebooks:**
# - `jupyter mcp fail.ipynb`
#
# The rest are 22Untitled notebooks (Untitled.ipynb through Untitled21.ipynb).
