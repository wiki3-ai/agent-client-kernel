# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# 🔧 bash (pending)✅ Tool 429678393 completed
# 🔧 bash (pending)✅ Tool 665341851 completed
# 🔧 bash (pending)✅ Tool 927581460 completed
# Here are the example notebooks in your `./examples/` directory:
#
# | Notebook | Description |
# |----------|-------------|
# | **ASCII ART.ipynb** | Create ASCII art with pi and Jupyter |
# | **basic_usage.ipynb** | Basic usage guide for the agent-client kernel |
# | **cat.ipynb** | Use pi with cat images (likely multimodal examples) |
# | **configuration_demo.ipynb** | Configuration options demo |
# | **function_plotter.ipynb** | Interactive function plotting with matplotlib |
# | **jupyter-mcp.ipynb** | Using MCP tools in Jupyter notebooks |
# | **matplotlib_functions.ipynb** | Advanced matplotlib examples with functions |
# | **rubiks_cube_combinatorics.ipynb** | Rubik's cube math/combinatorics |
# | **sum_squares.ipynb** | Simple sum of squares example |
# ...
