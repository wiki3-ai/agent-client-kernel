# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.tsI'll help you find the example notebooks in this project. Let me search for them.
# 🔧 bash (pending)✅ Tool 750798926 completed
# Let me get a cleaner view of the example notebooks in the `examples/` directory (excluding checkpoints):
# 🔧 bash (pending)✅ Tool 526210650 completed
# Here are the example notebooks in the `/workspaces/agent-client-kernel/examples/` directory:
# 1. **ASCII ART.ipynb** - 4.1 KB2. **basic_usage.ipynb** - 24 KB3. **cat.ipynb** - 34.8 KB4. **configuration_demo.ipynb** - 6 KB5. **function_plotter.ipynb** - 393.6 KB (large notebook)6. **jupyter-mcp.ipynb** - 6.8 KB7. **matplotlib_functions.ipynb** - 461 KB (largest notebook)8. **rubiks_cube_combinatorics.ipynb** - 22.7 KB9. **sum_squares.ipynb** - 1 KB10. **tiger_run.ipynb** - 45.5 KB11. **weather_map.ipynb** - 12.4 KB
# ...
