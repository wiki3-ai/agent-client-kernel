# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.tsI'll search for example notebooks in your project.
# 🔧 bash (pending)✅ Tool 121072002 completed
# Let me show you the example notebooks specifically in the `examples/` directory:
# 🔧 bash (pending)✅ Tool 192991343 completed
# Here are the example notebooks in your `examples/` directory:
# | Notebook | Size ||----------|------|| **ASCII ART.ipynb** | 4.1 KB || **basic_usage.ipynb** | 24 KB || **cat.ipynb** | 34.8 KB || **configuration_demo.ipynb** | 6 KB || **function_plotter.ipynb** | 393.6 KB (largest) || **jupyter-mcp.ipynb** | 6.8 KB || **sum_squares.ipynb** | 1 KB (smallest) || **tiger_run.ipynb** | 45.5 KB || **weather_map.ipynb** | 12.4 KB |
# Would you like me to show details about any specific notebook?

# %%
use the jupyter mcp to make the list
# Out:
# 🔧 mcp (pending)✅ Tool 322905020 completed
# 🔧 mcp (pending)✅ Tool 183672519 completed
# 🔧 mcp (pending)✅ Tool 420403912 completed
# Connected to the jupyter MCP server. Let me list the available notebooks:
# 🔧 mcp (pending)✅ Tool 966192769 completed
# 🔧 mcp (pending)✅ Tool 827346091 completed
# Here are the example notebooks listed via Jupyter MCP:
# | Notebook | Size | Last Modified ||----------|------|---------------|| `ASCII ART.ipynb` | 4.0 KB | 2026-04-30 05:59:47 || `basic_usage.ipynb` | 23.5 KB | 2026-04-27 22:33:55 || `cat.ipynb` | 34.0 KB | 2026-04-30 05:59:48 || `configuration_demo.ipynb` | 5.8 KB | 2026-04-27 22:33:55 || `function_plotter.ipynb` | 384.4 KB | 2026-04-28 22:03:22 || `jupyter-mcp.ipynb` | 6.6 KB | 2026-04-27 22:33:55 || `sum_squares.ipynb` | 987 B | 2026-04-28 22:03:08 || `tiger_run.ipynb` | 44.4 KB | 2026-04-30 05:59:45 || `weather_map.ipynb` | 12.1 KB | 2026-04-30 05:59:46 |

# %%
Make an example notebook that illustrates some combinatorics involved in analyzing solution space for Rubik's Cube.
Use the mcp tools for working with notebooks.
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.tsI'll create an example notebook that illustrates combinatorics involved in analyzing the Rubik's Cube solution space. Let me start by checking what MCP tools are available for working with notebooks.
# 🔧 mcp (pending)✅ Tool 459998649 completed
# 🔧 mcp (pending)✅ Tool 523291993 completed
# Let me first list the available notebooks to see if there are existing ones I should use or create a new one.
# 🔧 mcp (pending)✅ Tool 520494408 completed
# Good, there's a default notebook that's already activated. Now I'll create a comprehensive example notebook about Rubik's Cube combinatorics by inserting cells one by one.
# 🔧 mcp (pending)✅ Tool 725305414 completed
# Let me try again with the correct parameter format:
# 🔧 mcp (pending)✅ Tool 140210948 completed
# Let me try a simpler approach - using jupyter_use_notebook first:
# 🔧 mcp (pending)✅ Tool 919438177 completed
# ...
