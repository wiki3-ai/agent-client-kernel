# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# 🔧 bash (pending)✅ Tool 500550252 completed
# 🔧 bash (pending)✅ Tool 348328748 completed
# Here are the example notebooks in the `/workspaces/agent-client-kernel/examples` directory:
#
# | Notebook | Description ||----------|-------------|
# | `basic_usage.ipynb` | Basic usage guide |
# | `configuration_demo.ipynb` | Configuration demonstration |
# | `jupyter-mcp.ipynb` | Jupyter MCP integration |
# | `matplotlib_functions.ipynb` | Using matplotlib with functions |
# | `function_plotter.ipynb` | Function plotting example |
# | `ASCII ART.ipynb` | ASCII art generation |
# | `cat.ipynb` | Cat-related example |
# | `sum_squares.ipynb` | Sum of squares calculation |
# | `rubiks_cube_combinatorics.ipynb` | Rubik's cube combinatorics |
# | `tiger_run.ipynb` | Tiger run example |
# | `weather_map.ipynb` | Weather map visualization |
#
# Would you like me to describe any specific notebook in more detail?
