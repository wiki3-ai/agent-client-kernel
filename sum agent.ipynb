# %%
%agent mcp add jupyter uvx jupyter-mcp-server@latest
# Out:
# Added MCP server 'jupyter'. It will be available when the session starts.

# %%
%agent session restart

# %%
add a sum of squares example to the sum notebook.  use the mcp
# Out:
# I’m locating the target notebook through the Jupyter MCP tools first, then I’ll add a small sum-of-squares example directly in that notebook.
# 🔧 Tool: jupyter/list_notebooks (in_progress)
# ✅ Tool call_gY4nUGv74ayobS3Z4ZXXSd40 completed
#
# 🔧 Tool: jupyter/list_files (in_progress)
# The notebook search is narrowed down; I hit a tool-argument limit and am rerunning it with valid parameters.
# 🔧 Tool: jupyter/list_files (in_progress)
# ✅ Tool call_JNGGjh2kfoJV4AnNSKAZs8Vs completed
#
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_kI38ZqPrfbO8SfeyQatKv6Em completed
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
# ✅ Tool call_8ELLrK1wGKsfgg9tkXnznBSg completed
# I found `sum.ipynb`; it currently has a basic literal sum and a list sum. I’m appending a third code cell with a sum-of-squares example and executing it so the notebook output is populated.
# 🔧 Tool: jupyter/insert_execute_code_cell (in_progress)
# ✅ Tool call_KSFEubQ4gIbgeURE2ca50Act completed
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
# ✅ Tool call_hhIQ9mwk3H1VFOQlsYd37eA7 completed
# Added a sum-of-squares example to `sum.ipynb` using the Jupyter MCP tools. The new cell is:
#
# ```python
# numbers = [1, 2, 3, 4]
# sum(x**2 for x in numbers)
# ```
#
# I executed it as well; the output is `30`.
