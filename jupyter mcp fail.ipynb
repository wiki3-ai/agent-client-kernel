# %%
%agent mcp add jupyter uvx jupyter-mcp-server@latest
# Out:
# Added MCP server 'jupyter'. It will be available when the session starts.

# %%
hello
# Out:
# 💭 We💭  just💭  need💭  to💭  greet💭 .
# Hello! How can I assist you today?

# %%
what notebooks do we have? use the jupyter tools
# Out:
# 💭 We💭  need💭  list💭  files💭 .💭  Use💭  exec💭 _command💭  ls💭  *.💭 ip💭 yn💭 b💭 .
# 🔧 List /workspaces/agent-client-kernel/*.ipynb (in_progress)
# ✅ Tool call_1335458528970002 completed
# Here are the Jupyter notebooks currently in the workspace:
#
# - `Untitled.ipynb`
# - `Untitled1.ipynb`
# - `Untitled2.ipynb`
# - `Untitled3.ipynb`
# - `Untitled4.ipynb`
# - `Untitled5.ipynb`
# - `Untitled6.ipynb`
# - `Untitled7.ipynb`
# - `Untitled8.ipynb`
# - `Untitled9.ipynb`
# - `broadway.ipynb`
# - `jupyter mcp fail.ipynb`
# - `lmstudio agent.ipynb`
# - `sum agent.ipynb`
# - `sum.ipynb`
# - `weather agent.ipynb`

# %%
use the mcp tool
# Out:
# 💭 User💭  wants💭  to💭  use💭  MCP💭  tool💭 .💭  Lik💭 ely💭  list💭  resources💭 .💭  Use💭  list💭 _m💭 cp💭 _resources💭 .
# 🔧 Tool: codex/list_mcp_resources (in_progress)
# ✅ Tool call_1335458528970003 completed
# 💭 Provide💭  empty💭  string💭 .
# 🔧 Tool: codex/list_mcp_resources (in_progress)
# ✅ Tool call_1335458528970004 completed
# 💭 User💭  wants💭  use💭  m💭 cp💭  tool💭 ,💭  but💭  none💭  listed💭 .💭  Probably💭  no💭  resources💭 .💭  Respond💭  accordingly💭 .
# It looks like there are currently no MCP (Managed Content Provider) resources available in this environment, so there isn’t any additional data to pull in via the MCP tools at the moment. Let me know if there’s something else you’d like to explore or another way I can help!

# %%
%agent mcp
# Out:
# Configured MCP servers:
#   - jupyter: uvx jupyter-mcp-server@latest
