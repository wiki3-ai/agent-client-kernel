# %%
%agent mcp add paper_search python -m paper_search_mcp.server
# Out:
# Added MCP server 'paper_search'. It will be available when the session starts.

# %%
Please make a list of recent arXiv papers on the topic of hybrid KG for agentic reasoning.
# Out:
# I'll search for recent arXiv papers on hybrid knowledge graphs (KG) for agentic reasoning.
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390484 completed
# Let me try a broader search with related terms:
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390485 completed
# Let me try another approach with different terminology:
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390486 completed
#
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390487 completed
# Let me try searching for recent papers on knowledge graph reasoning without the specific hybrid/agentic terms:
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390488 completed
# Let me try one more search pattern:
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390489 completed
# ...

# %%
What do you get for machine learning?
# Out:
# 🔧 Tool: paper_search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390490 completed
# The arXiv search is returning empty results even for "machine learning". Let me try the other arXiv search tool available:
# 🔧 Tool: paper-search/search_arxiv (in_progress)
# ✅ Tool call_3695061130390491 completed
# Both arXiv search tools are returning empty results. This suggests there may be an issue with the MCP server configuration or connectivity to arXiv. Let me try searching Google Scholar instead:
# 🔧 Tool: paper_search/search_google_scholar (in_progress)
# ✅ Tool call_3695061130390492 completed
# The Google Scholar search works and returns results for "machine learning". The arXiv integration appears to have issues returning results.
#
# Let me try a more specific search on Google Scholar for your original topic:
# 🔧 Tool: paper_search/search_google_scholar (in_progress)
# ✅ Tool call_3695061130390493 completed
# ...
