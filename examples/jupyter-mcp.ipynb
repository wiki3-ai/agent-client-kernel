# %% [markdown]
# Install the datalayer/jupyter-mcp-server [https://github.com/datalayer/jupyter-mcp-server](https://github.com/datalayer/jupyter-mcp-server)

# %%
%agent mcp add jupyter uvx jupyter-mcp-server@latest
# Out:
# Added MCP server 'jupyter'. It will be available when the session starts.

# %%
make a notebook with python that computes the square root of the sum of the first 1000 squares
# Out:
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_pELwa1mqrcrboaCwPLlI881e completed
#
# 🔧 Tool: jupyter/insert_execute_code_cell (in_progress)
#
# 🔧 Tool: jupyter/list_notebooks (in_progress)
# ✅ Tool call_6ikYrGAzd1r2CthOAmCCTQlW completed
#
# 🔧 Tool: jupyter/insert_cell (in_progress)
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
#
# 🔧 Run cd /workspaces/agent-client-kernel/examples && python - <<'PY'
# import math
# n=1000
# s = sum(i*i for i in range(1,n+1))
# print(s)
# print(math.sqrt(s))
# PY (in_progress)
# ✅ Tool call_O1VgsIVzgsxP40hjYCYo2Lhy completed
#
# 🔧 Edit /workspaces/agent-client-kernel/examples/sqrt_first_1000_squares.ipynb (in_progress)
# ✅ Tool call_gEm3N9Uz58g8yXGrtUTezyZf completed
# Created `sqrt_first_1000_squares.ipynb` with a single Python cell computing `sqrt(sum(i*i for i in range(1, 1001)))`. Ran the calculation separately: result is `18271.111077326415`. Open the notebook and execute the cell to reproduce.

# %%
hello.  do you have jupyter mcp
# Out:
# 🔧 Tool: codex/list_mcp_resources (in_progress)
# ✅ Tool call_Ci2UWbgIgBRujWBkKfNr5xEF completed
#
# 🔧 Tool: codex/list_mcp_resource_templates (in_progress)
# ✅ Tool call_svZwP468U4ATPQVYAjGfKuNK completed
# No MCP servers/resources are registered in this session, so there isn’t a Jupyter MCP available right now. If you want, I can add/connect one (if you have a Jupyter MCP server endpoint or instructions).

# %%
%agent mcp add jupyter uvx jupyter-mcp-server@latest
# Out:
# Updated MCP server 'jupyter'

# %%
Activate the function_plotter notebook.
Add the ability to drag/pan/zoom/rescale the plot using the mouse (and should be touch compatible).
Keep to using the matplotlib and ipywidgets packages.  Only use the Jupyter MCP edits/execute/etc.
# Out:
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_DXgDBjFNZkUnn0ryXiym7vsE completed
#
# 🔧 List /workspaces/agent-client-kernel/examples (in_progress)
# ✅ Tool call_WaE9KPtEP1NIJJZL9DzZ6TU3 completed
#
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_usNsdHTGGIicMMqMSRGAlwjr completed
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
# ✅ Tool call_iZrdG8QdMsJSv8zLIpm1HEwd completed
#
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_X1Qiv56I9jpKcnDGeakoZBAP completed
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
#
# 🔧 Tool: jupyter/read_cell (in_progress)
#
# 🔧 Tool: jupyter/list_notebooks (in_progress)
# ✅ Tool call_s357zWK9BAbsDYYaERIC8c8o completed
#
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_4jjCTpF3spqYs4t3zf7l1O8Y completed
#
# 🔧 Tool: jupyter/execute_code (in_progress)
# ✅ Tool call_1Wdvo3N9AFDtzmAMe2bDMqdG completed
#
# 🔧 Tool: jupyter/execute_code (in_progress)
# ✅ Tool call_WhUIO4zwtMvJm5uCOoMjKRfM completed
#
# ...
