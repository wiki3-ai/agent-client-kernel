# %% [markdown]
# Install the datalayer/jupyter-mcp-server [https://github.com/datalayer/jupyter-mcp-server](https://github.com/datalayer/jupyter-mcp-server)

# %%
%agent mcp add jupyter uvx jupyter-mcp-server@latest
# Out:
# Added MCP server 'jupyter'

# %%
make a notebook with python that computes the sum of the first 100 squares
# Out:
# Added `sum_squares.ipynb` with a single Python cell that computes `sum(n * n for n in range(1, 101))` and leaves the result as the cell output ready to execute. You can open the notebook and run the cell to display the total.

# %%
hello.  do you have jupyter mcp
# Out:
# 🔧 **Tool Call**: Tool: codex/list_mcp_resource_templates (in_progress)
#
# 📋 **Tool Result**:
# {"resourceTemplates":[]}
# There isn’t a Jupyter MCP server configured in this environment. I can still help by writing or reviewing notebooks/scripts, running code/tests via the terminal, or guiding you on setting up a Jupyter MCP if you want.
