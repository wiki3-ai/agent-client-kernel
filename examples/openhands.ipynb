# %%
hello! what's your name?
# Out:
# 📜 Available commands: help, confirm
# 💭 System Prompt:
# System Prompt:
# You are OpenHands agent, a helpful AI assistant that can interact with a computer to solve tasks.
#
# <ROLE>
# * Your primary role is to assist users by executing commands, modifying code, and solving technical problems effectively. You should be thorough, methodical, and prioritize quality over speed.
# * If the user asks a question, like "why is X happening", don't try to fix the problem. Just give an answer to the question.
# </ROLE>
#
# <EFFICIENCY>
# * Each action you take is somewhat expensive. Wherever possible, combine multiple actions into a single action, e.g. combine multiple bash commands into one, using sed and grep to edit/view multiple files at once.
# * When exploring the codebase, use efficient tools like find, grep, and git commands with appropriate filters to minimize unnecessary operations.
# </EFFICIENCY>
#
# <FILE_SYSTEM_GUIDELINES>
# ...

# %%
what files do we have?  what processes are ruinning?
# Out:
# 🔧 ls -a && printf '\n' && ps aux (in_progress)
# 🔐 Permission requested for: Confirm Agent Actions   Options: Yes, proceed, Reject, Always proceed (don't ask again), Auto-confirm LOW/MEDIUM risk, ask for HIGH risk action   Mode: auto
# 📋 ls -a && printf '\n' && ps aux
# ...

# %%
%agent mcp add jupyter jupyter-mcp-server
# Out:
# Added MCP server 'jupyter'. Run `%agent session restart` to apply.

# %%
%agent session restart
# Out:
# 📜 Available commands: help, confirm
# Session restarted. Session ID: 694649c6-56ad-4e27-8c77-489228ad58dd

# %%
add a markdown cell to this (the active notebook) that says HELLO WORLD in big letters.  only use Jupyter MCP tools
# Out:
# 🔧 list_notebooks (in_progress)
# 🔐 Permission requested for: Confirm Agent Actions   Options: Yes, proceed, Reject, Always proceed (don't ask again), Auto-confirm LOW/MEDIUM risk, ask for HIGH risk action   Mode: auto📋 field_meta=None annotations=None text="Tool: list_notebooks\nResult:\n[MCP Tool 'list_notebooks' Observation]\n[Tool 'list_notebooks' executed.]\nName\tPath\tKernel_ID\tKernel_Status\tActivate\ndefault\tNone\t55d6f932-0979-45b3-a35c-57828bab0124\talive\t✓\n" type='text'✅ list_notebooks completed
# 🔧 use_notebook (in_progress)
# 📋 use_notebook
# ...

# %%
%agent status

# %%
%agent
