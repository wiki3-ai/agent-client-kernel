# %%
%agent mcp add jupyter uvx jupyter-mcp-server@latest
# Out:
# Added MCP server 'jupyter'. It will be available when the session starts.

# %%
add a markdown cell with ASCII art of a dragon to the end of this notebook
# Out:
# 🔧 Tool: jupyter/list_notebooks (in_progress)
# ✅ Tool call_Cwpv6nOsP9xiOiCPmouZ6VGC completed
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
#
# 🔧 Tool: jupyter/list_files (in_progress)
#
# 🔧 Tool: jupyter/list_files (in_progress)
# ✅ Tool call_d71spjbtjc1nmJPptgBzqd09 completed
#
# 🔧 Tool: jupyter/read_cell (in_progress)
#
# 🔧 Tool: jupyter/read_notebook (in_progress)
# ✅ Tool call_AF8mnjeh1F3K9LlUMR2cYzKe completed
#
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_xJDpMVM7X4X6QghUebbFX1kI completed
#
# 🔧 Tool: jupyter/read_cell (in_progress)
# ✅ Tool call_tgwlnWhIyBUEUeuQcXtNnEbZ completed
#
# 🔧 Tool: jupyter/insert_cell (in_progress)
# ✅ Tool call_mTCIWqavPFhHahDy70ytqPMR completed
# Added a new markdown cell at the end of `examples/cat.ipynb` with ASCII dragon art. Let me know if you want tweaks to the design.

# %%
That's cool but I meant the notebook I'm using right now: Untitled.
Does the Jupyter MCP not provide an indication of which notebook is active?
Please do another that is of an elephant.
# Out:
# 🔧 Tool: jupyter/use_notebook (in_progress)
# ✅ Tool call_lPZ5m3ypEFQTSOoxjAgoXSqC completed
#
# 🔧 Tool: jupyter/insert_cell (in_progress)
# ✅ Tool call_gcaZRXY59Pr6tiJKTeFYY751 completed
# Added a markdown cell with ASCII elephant art at the end of `examples/Untitled.ipynb`.
#
# On the active notebook question: the Jupyter MCP shows the currently activated notebook in the `use_notebook` confirmation and in `list_notebooks` (marked with a check). Right now, the active one is `Untitled` (`examples/Untitled.ipynb`).

# %% [markdown]
# ```
#      /\  ___  /\
#     (  \/   \/  )
#     |   O   O   |
#     |     ^     |
#     |  \_____/  |
#      \  /   \  /
#       \/     \/
#       /|     |\
#      / |  |  | \
#     /  |  |  |  \
#        |  |  |
#        |  |  |
#        |__|__|
#       /-_____-\
#       |       |
#       |       |
#       (_______)
# ```

# %% [markdown]
# ```
#                  ,w.
#                ,YWMMw  ,M  ,
#       _.---.._ dMMMMMP dMMP-.._
#    _/       `YMMMMMMMMMMMMMMP'\
#   /  ,gmmmm,  YMMMMMMMMMMMM'  \
#  |  dMMMMMMMm  `YMMMMMMMM'    |
#  |  YMMMMMMMMMm.  YMMMM'    __|
#  |  `YMMMMMMMMMMb  `YMMm.,mMMMM,
#   \   `YMMMMMMMMMMb. YMMMMMMMMM'
#    `._   `YMMMMMMMMMMb`YMMMMMP'
#       `-.__`YMMMMMMMMMMb._,'
#             `"YMMMMMMMP'
#                  `""'
# ```
