# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# 🔧 bash (pending)✅ Tool 270070025 completed
# 🔧 bash (pending)✅ Tool 200104101 completed
# Here are the example notebooks in your `/workspaces/agent-client-kernel/examples/` directory (excluding checkpoints):
#
# | Notebook | Description |
# |----------|-------------|
# | `ASCII ART.ipynb` | ASCII art generation example |
# | `basic_usage.ipynb` | Basic usage guide (24KB) |
# | `cat.ipynb` | Cat-related example (35KB) |
# | `configuration_demo.ipynb` | Configuration demonstration |
# | `function_plotter.ipynb` | Function plotting example (large file ~394KB) |
# | `jupyter-mcp.ipynb` | Jupyter MCP integration example |
# | `matplotlib_functions.ipynb` | Matplotlib functions plotting (very large ~461KB) |
# | `rubiks_cube_combinatorics.ipynb` | Rubik's cube combinatorics calculations |
# | `sum_squares.ipynb` | Sum of squares example (small) |
# | `tiger_run.ipynb` | Tiger run agent example |
# ...
