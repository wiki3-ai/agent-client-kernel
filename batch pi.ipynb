# %%
make a notebook in examples that using matplotlib to draw some function
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# Let me check one of the existing notebooks to understand the format and also see if there's already a matplotlib example:
#
# I can see there's already a `function_plotter.ipynb` in the examples folder. Let me create a simpler, focused example notebook specifically for matplotlib that demonstrates drawing various functions.
#
# Created a new notebook at `/workspaces/agent-client-kernel/examples/matplotlib_functions.ipynb` that demonstrates using matplotlib to draw various functions:
#
# 1. **Linear function** - y = 2x + 1
# 2. **Quadratic function** - y = x²
# 3. **Trigonometric functions** - sin(x) and cos(x)
# 4. **Exponential function** - y = eˣ
# 5. **Multiple functions** - comparing x, x², and x³ on one plot
# 6. **Polar plot** - r = sin(2θ)
# 7. **Custom styling** - damped sine wave with custom colors and markers
#
# ...
