# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# 🔧 bash (pending)✅ Tool 242733843 completed
# Let me look for example notebooks in a more specific way - checking if there's an examples directory or documentation:
# 🔧 bash (pending)✅ Tool 997515855 completed
# 🔧 bash (pending)✅ Tool 407387039 completed
# Here are the example notebooks in `/workspaces/agent-client-kernel/examples/`:
# ...
