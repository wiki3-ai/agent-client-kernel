# %%
what example notebooks do we have?
# Out:
# pi v0.74.0
# ---
#
# ## Extensions
# - npm:pi-mcp-adapter
#   - index.ts
# 🔧 bash (pending)✅ Tool 358926463 completed
# Let me look for example notebooks in a more specific way - checking for common example directories:
# 🔧 bash (pending)✅ Tool 436929440 completed
# I see there's an `examples` directory. Let me check what's in there:
# 🔧 bash (pending)✅ Tool 583217671 completed
# Here are the **example notebooks** in this project:
#
# ## Main Examples (`/workspaces/agent-client-kernel/examples/`)
#
# 1. **basic_usage.ipynb** - Basic usage guide
# 2. **ASCII ART.ipynb** - ASCII art generation example
# 3. **cat.ipynb** - Cat-related example
# 4. **configuration_demo.ipynb** - Configuration demonstration
# 5. **function_plotter.ipynb** - Function plotting example
# 6. **jupyter-mcp.ipynb** - Jupyter MCP integration
# 7. **matplotlib_functions.ipynb** - Matplotlib functions example
# 8. **rubiks_cube_combinatorics.ipynb** - Rubik's cube combinatorics
# ...
